# %%
from langgraph.graph import StateGraph, START, END
from langchain_core.messages import HumanMessage, SystemMessage
from typing import TypedDict, Literal, Annotated
from langchain_huggingface import HuggingFaceEndpoint, ChatHuggingFace
from pydantic import BaseModel, Field

# %%
class TweetEvaluation(BaseModel):
    evaluation: Literal["approved", 'needs improvement'] = Field(..., description="Final Evaluation")
    feedback: str = Field(..., description="feedback for the tweet")

# %%
# structured_evaluator_llm =

# %%
class MyState(TypedDict):
    topic: str
    tweeter: str
    evaluator: Literal["approved", 'needs improvement']
    feedback: str
    iteration: int
    max_iteration: int

# %%
def genrate_tweet(state: MyState) -> MyState:
    pass

def evaluate_tweet(state: MyState) -> MyState:
    pass

def optimize_tweet(state: MyState) -> MyState:
    pass

# %%
graph = StateGraph(MyState)

graph.add_node('genrate', genrate_tweet)
graph.add_node('evaluate', evaluate_tweet)
graph.add_node('optimize', optimize_tweet)
